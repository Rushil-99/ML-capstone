# %% [markdown]
# # Clustering Track
#
# 23CSE301 ML Capstone — Review 2
#
# K-Means and Agglomerative Hierarchical Clustering. Ground-truth labels used only for post-hoc validation.

# %% [markdown]
# ## 1. Dataset Loading & Audit

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
sns.set_theme(style="whitegrid", palette="colorblind")

# %%
# TODO: load the assigned clustering dataset
# df = pd.read_csv('../data/<clustering_dataset>.csv')

# %% [markdown]
# ## 2. Preprocessing
#
# Scaling/encoding as needed prior to clustering.

# %%
# TODO: preprocessing

# %% [markdown]
# ## 3. K-Means Clustering
#
# Elbow curve (inertia vs. k) to choose k.

# %%
# TODO: K-Means + elbow curve

# %% [markdown]
# ## 4. Agglomerative Hierarchical Clustering
#
# Dendrogram; compare linkage strategies.

# %%
# TODO: Agglomerative clustering + dendrogram

# %% [markdown]
# ## 5. Evaluation Metrics
#
# Silhouette Score, Davies-Bouldin Index, Calinski-Harabasz Index for both algorithms.

# %%
# TODO: metrics table

# %% [markdown]
# ## 6. Cluster Visualisation
#
# PCA (2 components) scatter plot per algorithm, colour-coded by cluster; t-SNE for at least one algorithm.

# %%
# TODO: PCA / t-SNE visualisations

# %% [markdown]
# ## 7. Post-hoc Validation Against Ground Truth
#
# Compare cluster assignments to known labels (if available) for interpretation only.

# %%
# TODO: post-hoc comparison
